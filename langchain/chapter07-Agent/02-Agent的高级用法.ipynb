# %% [markdown]
# # Agent高级用法
# ## 设置 agent名称
# ### 使用字段name来进行设置

# %%
import os
from dotenv import load_dotenv
from langchain_core.tools import tool

from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from rich import print as rprint

load_dotenv(override=True)
ARK_API_KEY = os.getenv("ARK_API_KEY")
ARK_MODEL_NAME = os.getenv("ARK_MODEL_NAME")
ARK_BASE_URL = os.getenv("ARK_BASE_URL")
model = ChatOpenAI(
    model= ARK_MODEL_NAME,
    api_key= ARK_API_KEY,
    base_url= ARK_BASE_URL
)


agent = create_agent(
    model = model,
    name = "agent1"
)

#调用
response = agent.invoke({
    "messages":["你的名字是？"]
})

rprint(response)
# Out:
# c:\Users\XSH\.conda\envs\langchain1.2\Lib\site-packages\requests\__init__.py:92: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# {
#     'messages': [
#         HumanMessage(
#             content='你的名字是？',
#             additional_kwargs={},
#             response_metadata={},
#             id='14237633-0185-4a5d-93ae-3a09af51624f'
#         ),
#         AIMessage(
#             content='我是GLM，由Z.ai开发的大语言模型。我被设计用来帮助用户回答问题、提供信息和进行各类对话交流。\n\
# n很高兴认识你！有什么我能帮你解答或探讨的话题吗？',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 191,
#                     'prompt_tokens': 16,
#                     'total_tokens': 207,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': None,
#                         'audio_tokens': None,
# ...

# %%
import os
from dotenv import load_dotenv
from langchain_core.tools import tool

from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from rich import print as rprint

load_dotenv(override=True)
ARK_API_KEY = os.getenv("ARK_API_KEY")
ARK_MODEL_NAME = os.getenv("ARK_MODEL_NAME")
ARK_BASE_URL = os.getenv("ARK_BASE_URL")
model = ChatOpenAI(
    model= ARK_MODEL_NAME,
    api_key= ARK_API_KEY,
    base_url= ARK_BASE_URL
)


agent = create_agent(
    model = model,
    name = "agent1"
)

#调用
response = agent.invoke({
    "messages":["你的名字是？"]
})

for message in response["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 你的名字是？
# ================================== Ai Message ==================================
# Name: agent1
#
# 我是一个由Z.ai训练的大型语言模型，你可以叫我GLM。我的目标是根据广泛的训练数据提供信息、回答问题和生成文本。
#
# 很高兴认识你！有什么我可以帮你的吗？

# %% [markdown]
# ## 系统提示词的设置
# 使用system_prompt,str,systemmessage

# %%
import os
from dotenv import load_dotenv
from langchain_core.tools import tool

from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from rich import print as rprint

load_dotenv(override=True)
ARK_API_KEY = os.getenv("ARK_API_KEY")
ARK_MODEL_NAME = os.getenv("ARK_MODEL_NAME")
ARK_BASE_URL = os.getenv("ARK_BASE_URL")
model = ChatOpenAI(
    model= ARK_MODEL_NAME,
    api_key= ARK_API_KEY,
    base_url= ARK_BASE_URL
)

#定义工具
def search_movie(keyword: str):
    """
    根据关键词搜索电影

    Args:
        keyword: 搜索关键词，例如 "科幻"、"诺兰"
    """
    fake_db = {
        "科幻": ["星际穿越", "盗梦空间", "降临"],
        "诺兰": ["星际穿越", "盗梦空间", "信条"],
        "宫崎骏": ["千与千寻", "龙猫", "天空之城"],
    }
    results = fake_db.get(keyword, [])
    if results:
        return f"关于「{keyword}」的电影有：{', '.join(results)}"
    return f"没有找到关于「{keyword}」的电影"

agent = create_agent(
    model = model,
    tools=[search_movie],
    system_prompt="你是一名资深的电影爱好者"
)

#调用
response = agent.invoke({
    "messages":["请为我推荐一部诺兰的电影"]
})

rprint(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='请为我推荐一部诺兰的电影',
#             additional_kwargs={},
#             response_metadata={},
#             id='867059cc-fd37-4e73-8752-642f6e53abfe'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 46,
#                     'prompt_tokens': 186,
#                     'total_tokens': 232,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': None,
#                         'audio_tokens': None,
#                         'reasoning_tokens': 34,
#                         'rejected_prediction_tokens': None,
#                         'text_tokens': None
#                     },
#                     'prompt_tokens_details': {
#                         'audio_tokens': None,
# ...

# %%
import os
from dotenv import load_dotenv
from langchain_core.tools import tool

from langchain_core.messages import SystemMessage
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from rich import print as rprint

load_dotenv(override=True)
ARK_API_KEY = os.getenv("ARK_API_KEY")
ARK_MODEL_NAME = os.getenv("ARK_MODEL_NAME")
ARK_BASE_URL = os.getenv("ARK_BASE_URL")
model = ChatOpenAI(
    model= ARK_MODEL_NAME,
    api_key= ARK_API_KEY,
    base_url= ARK_BASE_URL
)

#定义工具
def search_movie(keyword: str):
    """
    根据关键词搜索电影

    Args:
        keyword: 搜索关键词，例如 "科幻"、"诺兰"
    """
    fake_db = {
        "科幻": ["星际穿越", "盗梦空间", "降临"],
        "诺兰": ["星际穿越", "盗梦空间", "信条"],
        "宫崎骏": ["千与千寻", "龙猫", "天空之城"],
    }
    results = fake_db.get(keyword, [])
    if results:
        return f"关于「{keyword}」的电影有：{', '.join(results)}"
    return f"没有找到关于「{keyword}」的电影"

agent = create_agent(
    model = model,
    tools=[search_movie],
    # system_prompt="你是一名资深的电影爱好者"
    system_prompt= SystemMessage(content = "你是一名资深的电影爱好者")
)

#调用
response = agent.invoke({
    "messages":["请为我推荐一部诺兰的电影"]
})

rprint(response)

# %% [markdown]
# ## 模型格式化输出

# %%
import os
from dotenv import load_dotenv
from langchain_core.tools import tool

from langchain.agents.structured_output import ProviderStrategy 
from langchain_core.messages import SystemMessage
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from pydantic import BaseModel, Field
from rich import print as rprint

load_dotenv(override=True)
ARK_API_KEY = os.getenv("ARK_API_KEY")
ARK_MODEL_NAME = os.getenv("ARK_MODEL_NAME")
ARK_BASE_URL = os.getenv("ARK_BASE_URL")
model = ChatOpenAI(
    model= ARK_MODEL_NAME,
    api_key= ARK_API_KEY,
    base_url= ARK_BASE_URL
)
#使用pydantic结构化方法进行定义

class ContraactInfo(BaseModel):
    '''用户联系方式'''
    name : str = Field(description="用户姓名")
    email : str = Field(description="用户邮箱")
    phone : str = Field(description="用户电话")


agent = create_agent(
    model = model, 
    response_format= ProviderStrategy(ContraactInfo)
)

#调用
response = agent.invoke({
    "messages": [
        "请以客服『张三』的身份回复我，邮箱 zhangsan@example.com，电话 138-0000-1234"
    ]
})

rprint(response)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_openai\chat_models\base.py:1867, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1865 payload.pop("stream")
#    1866 raw_response = (
# -> 1867     self.root_client.chat.completions.with_raw_response.parse(**payload)
#    1868 )
#    1869 response = raw_response.parse()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\openai\_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# ...

# %% [markdown]
# ProviderStrategy 的设计前提是让模型直接使用 provider 原生的 JSON Schema 结构化输出能力。然而你的 ARK 模型（或该模型当前部署的版本）并不支持 response_format.type = "json_schema"，所以服务端直接返回了 400 参数错误。
#
# 使用小众模型导致的，后面试试换成deepseek的模型

# %% [markdown]
# toolStrategy结构化输出

# %%
import os
from dotenv import load_dotenv
from langchain_core.tools import tool

from langchain.agents.structured_output import ToolStrategy 
from langchain_core.messages import SystemMessage
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from pydantic import BaseModel, Field
from rich import print as rprint

load_dotenv(override=True)
ARK_API_KEY = os.getenv("ARK_API_KEY")
ARK_MODEL_NAME = os.getenv("ARK_MODEL_NAME")
ARK_BASE_URL = os.getenv("ARK_BASE_URL")
model = ChatOpenAI(
    model= ARK_MODEL_NAME,
    api_key= ARK_API_KEY,
    base_url= ARK_BASE_URL
)
#使用pydantic结构化方法进行定义

class ContraactInfo(BaseModel):
    '''用户联系方式'''
    name : str = Field(description="用户姓名")
    email : str = Field(description="用户邮箱")
    phone : str = Field(description="用户电话")


agent = create_agent(
    model = model, 
    response_format= ToolStrategy(ContraactInfo)
)

#调用
response = agent.invoke({
    "messages": [
        "请以客服『张三』的身份回复我，邮箱 zhangsan@example.com，电话 138-0000-1234"
    ]
})

rprint(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='请以客服『张三』的身份回复我，邮箱 zhangsan@example.com，电话 138-0000-1234',
#             additional_kwargs={},
#             response_metadata={},
#             id='d68e2805-5ece-4a62-a45a-74af2ec673ae'
#         ),
#         AIMessage(
#             content='好的，我已收到您的身份信息，现在为您登记联系方式：',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 212,
#                     'prompt_tokens': 224,
#                     'total_tokens': 436,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': None,
#                         'audio_tokens': None,
#                         'reasoning_tokens': 162,
#                         'rejected_prediction_tokens': None,
#                         'text_tokens': None
#                     },
#                     'prompt_tokens_details': {
# ...

# %% [markdown]
# AutoStrategy/type

# %%
import os
from dotenv import load_dotenv
from langchain_core.tools import tool

from langchain.agents.structured_output import AutoStrategy 
from langchain_core.messages import SystemMessage
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from pydantic import BaseModel, Field
from rich import print as rprint

load_dotenv(override=True)
ARK_API_KEY = os.getenv("ARK_API_KEY")
ARK_MODEL_NAME = os.getenv("ARK_MODEL_NAME")
ARK_BASE_URL = os.getenv("ARK_BASE_URL")
model = ChatOpenAI(
    model= ARK_MODEL_NAME,
    api_key= ARK_API_KEY,
    base_url= ARK_BASE_URL
)
#使用pydantic结构化方法进行定义

class ContraactInfo(BaseModel):
    '''用户联系方式'''
    name : str = Field(description="用户姓名")
    email : str = Field(description="用户邮箱")
    phone : str = Field(description="用户电话")


agent = create_agent(
    model = model, 
    response_format= AutoStrategy(ContraactInfo)
)

#调用
response = agent.invoke({
    "messages": [
        "请以客服『张三』的身份回复我，邮箱 zhangsan@example.com，电话 138-0000-1234"
    ]
})

rprint(response)
